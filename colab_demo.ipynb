# %% [markdown]
# # GPT-J-6B Inference Demo
#
# <a href="http://colab.research.google.com/github/kingoflolz/mesh-transformer-jax/blob/master/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This notebook demonstrates how to run the [GPT-J-6B model](https://github.com/kingoflolz/mesh-transformer-jax/#GPT-J-6B). See the link for more details about the model, including evaluation metrics and credits.

# %% [markdown]
# ## Install Dependencies
#
# First we download the model and install some dependencies. This step takes at least 5 minutes (possibly longer depending on server load).
#
# !!! **Make sure you are using a TPU runtime!** !!!

# %%
# !apt install zstd

# the "slim" version contain only bf16 weights and no optimizer parameters, which minimizes bandwidth and memory
# !time wget -c https://the-eye.eu/public/AI/GPT-J-6B/step_383500_slim.tar.zstd

# !time tar -I zstd -xf step_383500_slim.tar.zstd

# !git clone https://github.com/kingoflolz/mesh-transformer-jax.git
# !pip install -r mesh-transformer-jax/requirements.txt

# jax 0.2.12 is required due to a regression with xmap in 0.2.13
# !pip install mesh-transformer-jax/ jax==0.2.12 tensorflow==2.5.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# zstd is already the newest version (1.4.4+dfsg-3ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# --2023-04-27 18:30:48--  https://the-eye.eu/public/AI/GPT-J-6B/step_383500_slim.tar.zstd
# Resolving the-eye.eu (the-eye.eu)... 162.213.130.6
# Connecting to the-eye.eu (the-eye.eu)|162.213.130.6|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
#
# real	0m0.264s
# user	0m0.008s
# sys	0m0.004s
#
# real	1m41.130s
# user	0m26.379s
# sys	0m34.147s
# fatal: destination path 'mesh-transformer-jax' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness/ (from -r mesh-transformer-jax/requirements.txt (line 9))
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness/ to /tmp/pip-req-build-gwaecy46
#   Running command git clone --filter=blob:none --quiet https://github.com/EleutherAI/lm-evaluation-harness/ /tmp/pip-req-build-gwaecy46
#   Resolved https://github.com/EleutherAI/lm-evaluation-harness/ to commit e47e01beea79cfe87421e2dac49e64d499c240b4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy~=1.19.5 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: tqdm>=4.45.0 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: wandb>=0.11.2 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 3)) (0.15.0)
# Requirement already satisfied: einops~=0.3.0 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: requests~=2.25.1 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 5)) (2.25.1)
# Requirement already satisfied: fabric~=2.6.0 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 6)) (2.6.0)
# Requirement already satisfied: optax==0.0.9 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 7)) (0.0.9)
# Requirement already satisfied: dm-haiku==0.0.5 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 8)) (0.0.5)
# Requirement already satisfied: ray[default]==1.4.1 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: jax~=0.2.12 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: Flask~=1.1.2 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 12)) (1.1.4)
# Requirement already satisfied: cloudpickle~=1.3.0 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: tensorflow-cpu~=2.6.0 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 14)) (2.6.5)
# Requirement already satisfied: google-cloud-storage~=1.36.2 in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 15)) (1.36.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 16)) (4.28.1)
# Requirement already satisfied: smart_open[gcs] in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 17)) (6.2.0)
# Requirement already satisfied: func_timeout in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 18)) (4.3.5)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 19)) (6.1.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 20)) (0.95.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 21)) (0.21.1)
# Requirement already satisfied: lm_dataformat in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 22)) (0.0.20)
# Requirement already satisfied: pathy in /usr/local/lib/python3.9/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 23)) (0.10.1)
# Requirement already satisfied: chex>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.5)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.9/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.4.7)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.9/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (0.8.10)
# Requirement already satisfied: jmp>=0.0.2 in /usr/local/lib/python3.9/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (0.0.4)
# Requirement already satisfied: redis>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.5.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (7.1.2)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.19.6)
# Requirement already satisfied: gpustat in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.1)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.8.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.0.5)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.3.3)
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: pydantic>=1.8 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.9.2)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.34.1)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.11.2)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (6.0)
# Requirement already satisfied: aioredis in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.3.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.11.0)
# Requirement already satisfied: colorful in /usr/local/lib/python3.9/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.5.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (67.7.2)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (1.21.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (3.7.4.3)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (3.1.31)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2022.12.7)
# Requirement already satisfied: pathlib2 in /usr/local/lib/python3.9/dist-packages (from fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (2.3.7.post1)
# Requirement already satisfied: invoke<2.0,>=1.3 in /usr/local/lib/python3.9/dist-packages (from fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.7.3)
# Requirement already satisfied: paramiko>=2.4 in /usr/local/lib/python3.9/dist-packages (from fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.11.0)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.1.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.8.4)
# Requirement already satisfied: openai>=0.6.4 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.27.5)
# Requirement already satisfied: omegaconf>=2.2 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: peft>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: pybind11>=2.6.2 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.10.4)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (22.3.5)
# Requirement already satisfied: pytablewriter in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.64.2)
# Requirement already satisfied: rouge-score>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: sacrebleu==1.5.0 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.2.2)
# Requirement already satisfied: sqlitedict in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.1.0)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.0.0+cu118)
# Requirement already satisfied: tqdm-multiprocess in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.0.11)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.9/dist-packages (from lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.21.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.9/dist-packages (from sacrebleu==1.5.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.7.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.9/dist-packages (from jax~=0.2.12->-r mesh-transformer-jax/requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.9/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.9/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.9/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.2.0)
# Collecting grpcio>=1.28.1
#   Downloading grpcio-1.54.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.15.0)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.2)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.40.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (5.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.12)
# Requirement already satisfied: keras<2.7,>=2.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (2.6.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.3.3)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.35.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.7.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (0.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (0.14.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->-r mesh-transformer-jax/requirements.txt (line 19)) (0.2.6)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /usr/local/lib/python3.9/dist-packages (from fastapi->-r mesh-transformer-jax/requirements.txt (line 20)) (0.26.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/dist-packages (from uvicorn->-r mesh-transformer-jax/requirements.txt (line 21)) (0.14.0)
# Requirement already satisfied: ujson in /usr/local/lib/python3.9/dist-packages (from lm_dataformat->-r mesh-transformer-jax/requirements.txt (line 22)) (5.7.0)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from pathy->-r mesh-transformer-jax/requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.9/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.3.6)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (9.0.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2023.4.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.70.14)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.4.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.18.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets>=2.0.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (4.0.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.9)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.21.0 in /usr/local/lib/python3.9/dist-packages (from google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (2.10.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.9/dist-packages (from google-resumable-media<2.0dev,>=1.2.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.5.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jaxlib>=0.1.37->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jaxlib>=0.1.37->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.0)
# Collecting jaxlib>=0.1.37
#   Using cached jaxlib-0.4.6-cp39-cp39-manylinux2014_x86_64.whl (62.0 MB)
#   Using cached jaxlib-0.4.4-cp39-cp39-manylinux2014_x86_64.whl (72.6 MB)
#   Using cached jaxlib-0.4.3-cp39-cp39-manylinux2014_x86_64.whl (72.2 MB)
#   Using cached jaxlib-0.4.2-cp39-cp39-manylinux2014_x86_64.whl (71.9 MB)
#   Using cached jaxlib-0.4.1-cp39-cp39-manylinux2014_x86_64.whl (71.3 MB)
#   Using cached jaxlib-0.3.25-cp39-cp39-manylinux2014_x86_64.whl (71.2 MB)
#   Using cached jaxlib-0.3.24-cp39-cp39-manylinux2014_x86_64.whl (70.0 MB)
#   Using cached jaxlib-0.3.22-cp39-cp39-manylinux2014_x86_64.whl (72.0 MB)
#   Using cached jaxlib-0.3.20-cp39-cp39-manylinux2014_x86_64.whl (72.2 MB)
#   Using cached jaxlib-0.3.15-cp39-none-manylinux2014_x86_64.whl (72.0 MB)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.9/dist-packages (from Jinja2<3.0,>=2.10.1->Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.1.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/dist-packages (from omegaconf>=2.2->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (4.9.3)
# Requirement already satisfied: bcrypt>=3.2 in /usr/local/lib/python3.9/dist-packages (from paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (4.0.1)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.9/dist-packages (from paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (40.0.2)
# Requirement already satisfied: pynacl>=1.5 in /usr/local/lib/python3.9/dist-packages (from paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.9/dist-packages (from peft>=0.2.0->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.18.0)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.9/dist-packages (from redis>=3.5.0->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from rouge-score>=0.0.4->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.9/dist-packages (from starlette<0.27.0,>=0.26.1->fastapi->-r mesh-transformer-jax/requirements.txt (line 20)) (3.6.2)
# Collecting typing-extensions
#   Using cached typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.4.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.25.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (23.1.0)
# Requirement already satisfied: blessed>=1.17.1 in /usr/local/lib/python3.9/dist-packages (from gpustat->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.20.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /usr/local/lib/python3.9/dist-packages (from gpustat->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (11.525.112)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.19.3)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.9/dist-packages (from opencensus->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.1.3)
# Requirement already satisfied: typepy[datetime]<2,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: DataProperty<2,>=0.55.0 in /usr/local/lib/python3.9/dist-packages (from pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.55.0)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.2)
# Requirement already satisfied: pathvalidate<3,>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.5.2)
# Requirement already satisfied: tabledata<2,>=1.3.0 in /usr/local/lib/python3.9/dist-packages (from pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi->-r mesh-transformer-jax/requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=3.3->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core<3.0.0dev,>=1.21.0->google-cloud-core<2.0dev,>=1.4.1->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.59.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (6.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.4.8)
# Requirement already satisfied: pytz>=2018.9 in /usr/local/lib/python3.9/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2022.7.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.9/dist-packages (from typepy[datetime]<2,>=1.2.0->pytablewriter->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.8.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7->lm-eval==0.3.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (2.21)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.2.2)
# Installing collected packages: typing-extensions, tensorflow-estimator, grpcio, jaxlib
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.7
#     Uninstalling jaxlib-0.4.7:
#       Successfully uninstalled jaxlib-0.4.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.5.0 requires grpcio~=1.34.0, but you have grpcio 1.54.0 which is incompatible.
# tensorflow 2.5.0 requires tensorflow-estimator<2.6.0,>=2.5.0rc0, but you have tensorflow-estimator 2.6.0 which is incompatible.
# tensorflow 2.5.0 requires typing-extensions~=3.7.4, but you have typing-extensions 3.10.0.2 which is incompatible.
# sqlalchemy 2.0.9 requires typing-extensions>=4.2.0, but you have typing-extensions 3.10.0.2 which is incompatible.
# polars 0.17.3 requires typing_extensions>=4.0.1; python_version < "3.11", but you have typing-extensions 3.10.0.2 which is incompatible.
# orbax 0.1.7 requires jax>=0.4.6, but you have jax 0.2.12 which is incompatible.
# librosa 0.10.0.post2 requires numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3, but you have numpy 1.19.5 which is incompatible.
# librosa 0.10.0.post2 requires typing-extensions>=4.1.1, but you have typing-extensions 3.10.0.2 which is incompatible.
# flax 0.6.8 requires jax>=0.4.2, but you have jax 0.2.12 which is incompatible.
# flax 0.6.8 requires typing-extensions>=4.1.1, but you have typing-extensions 3.10.0.2 which is incompatible.
# arviz 0.15.1 requires numpy>=1.20.0, but you have numpy 1.19.5 which is incompatible.
# arviz 0.15.1 requires typing-extensions>=4.1.0, but you have typing-extensions 3.10.0.2 which is incompatible.
# Successfully installed grpcio-1.54.0 jaxlib-0.3.15 tensorflow-estimator-2.6.0 typing-extensions-3.10.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./mesh-transformer-jax
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jax==0.2.12 in /usr/local/lib/python3.9/dist-packages (0.2.12)
# Requirement already satisfied: tensorflow==2.5.0 in /usr/local/lib/python3.9/dist-packages (2.5.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.9/dist-packages (from jax==0.2.12) (3.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.9/dist-packages (from jax==0.2.12) (0.15.0)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.9/dist-packages (from jax==0.2.12) (1.19.5)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (1.1.2)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (1.1.0)
# Collecting typing-extensions~=3.7.4
#   Using cached typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (0.2.0)
# Collecting grpcio~=1.34.0
#   Using cached grpcio-1.34.1-cp39-cp39-manylinux2014_x86_64.whl (4.0 MB)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (2.5.0.dev2021032900)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (1.12)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (3.19.6)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (0.4.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (0.40.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (3.1.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.5.0) (1.15.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.25.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (67.7.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.9)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (6.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.26.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.2.2)
# Building wheels for collected packages: mesh-transformer
#   Building wheel for mesh-transformer (setup.py) ... done
#   Created wheel for mesh-transformer: filename=mesh_transformer-0.0.0-py3-none-any.whl size=26320 sha256=452670893caa31e003b481cc7f0ce557c6ef7d7a69832311effcfa2eb74294cb
#   Stored in directory: /root/.cache/pip/wheels/98/1b/3b/3f75d9ff72d2c7077f57db125af6ade831cc8127beab0fbcef
# Successfully built mesh-transformer

# %%
pip install --upgrade --no-deps --force-reinstall jaxlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jaxlib
#   Using cached jaxlib-0.4.7-cp39-cp39-manylinux2014_x86_64.whl (66.1 MB)
# Installing collected packages: jaxlib
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.3.15
#     Uninstalling jaxlib-0.3.15:
#       Successfully uninstalled jaxlib-0.3.15
# Successfully installed jaxlib-0.4.7

# %% [markdown]
# ## Setup Model

# %%
import os
import requests 
from jax.config import config

colab_tpu_addr = os.environ['COLAB_TPU_ADDR'].split(':')[0]
url = f'http://{colab_tpu_addr}:8475/requestversion/tpu_driver0.1_dev20210607'
requests.post(url)

# The following is required to use TPU Driver as JAX's backend.
config.FLAGS.jax_xla_backend = "tpu_driver"
config.FLAGS.jax_backend_target = "grpc://" + os.environ['COLAB_TPU_ADDR']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-c95279dac08d> in <cell line: 3>()
#       1 import os
#       2 import requests
# ----> 3 from jax.config import config
#       4
#       5 colab_tpu_addr = os.environ['COLAB_TPU_ADDR'].split(':')[0]
#
# /usr/local/lib/python3.9/dist-packages/jax/__init__.py in <module>
#      96   xla_computation,
#      97 )
# ---> 98 from .experimental.maps import soft_pmap
#      99 from .version import __version__
#     100
#
# /usr/local/lib/python3.9/dist-packages/jax/experimental/maps.py in <module>
#      23 from functools import wraps, partial
#      24
# ---> 25 from .. import numpy as jnp
#      26 from .. import core
#      27 from .. import linear_util as lu
#
# /usr/local/lib/python3.9/dist-packages/jax/numpy/__init__.py in <module>
#      14
#      15 # flake8: noqa: F401
# ---> 16 from . import fft
#      17 from . import linalg
#      18
#
# /usr/local/lib/python3.9/dist-packages/jax/numpy/fft.py in <module>
#      15 # flake8: noqa: F401
#      16
# ---> 17 from jax._src.numpy.fft import (
#      18   ifft,
#      19   ifft2,
#
# /usr/local/lib/python3.9/dist-packages/jax/_src/numpy/fft.py in <module>
#      16 import numpy as np
#      17
# ---> 18 from jax import lax
#      19 from jax.lib import xla_client
#      20 from .util import _wraps
#
# /usr/local/lib/python3.9/dist-packages/jax/lax/__init__.py in <module>
#     326   while_p,
#     327 )
# --> 328 from jax._src.lax.fft import (
#     329   fft,
#     330   fft_p,
#
# /usr/local/lib/python3.9/dist-packages/jax/_src/lax/fft.py in <module>
#     141 batching.primitive_batchers[fft_p] = fft_batching_rule
#     142 if pocketfft:
# --> 143   xla.backend_specific_translations['cpu'][fft_p] = pocketfft.pocketfft
#
# AttributeError: module 'jaxlib.pocketfft' has no attribute 'pocketfft'

# %% [markdown]
# Sometimes the next step errors for some reason, just run it again ¯\\\_(ツ)\_/¯

# %%
import time

import jax
from jax.experimental import maps
import numpy as np
import optax
import transformers

from mesh_transformer.checkpoint import read_ckpt_lowmem
from mesh_transformer.sampling import nucleaus_sample
from mesh_transformer.transformer_shard import CausalTransformer

# %%
params = {
  "layers": 28,
  "d_model": 4096,
  "n_heads": 16,
  "n_vocab": 50400,
  "norm": "layernorm",
  "pe": "rotary",
  "pe_rotary_dims": 64,

  "seq": 2048,
  "cores_per_replica": 8,
  "per_replica_batch": 1,
}

per_replica_batch = params["per_replica_batch"]
cores_per_replica = params["cores_per_replica"]
seq = params["seq"]


params["sampler"] = nucleaus_sample

# here we "remove" the optimizer parameters from the model (as we don't need them for inference)
params["optimizer"] = optax.scale(0)

mesh_shape = (jax.device_count() // cores_per_replica, cores_per_replica)
devices = np.array(jax.devices()).reshape(mesh_shape)

maps.thread_resources.env = maps.ResourceEnv(maps.Mesh(devices, ('dp', 'mp')))

tokenizer = transformers.GPT2TokenizerFast.from_pretrained('gpt2')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1042301.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1355256.0, style=ProgressStyle(descript…

# %% [markdown]
# Here we create the network and load the parameters from the downloaded files. Expect this to take around 5 minutes.

# %%
total_batch = per_replica_batch * jax.device_count() // cores_per_replica

network = CausalTransformer(params)

network.state = read_ckpt_lowmem(network.state, "step_383500/", devices.shape[1])

network.state = network.move_xmap(network.state, np.zeros(cores_per_replica))
# Out:
# /usr/local/lib/python3.7/dist-packages/jax/experimental/maps.py:412: UserWarning: xmap is an experimental feature and probably has bugs!
#   warn("xmap is an experimental feature and probably has bugs!")
# key shape (8, 2)
# in shape (1, 2048)
# dp 1
# mp 8
# read from gcs in 22.633s

# %% [markdown]
# ## Run Model
#
# Finally, we are ready to infer with the model! The first sample takes around a minute due to compilation, but after that it should only take about 10 seconds per sample.
#
# Feel free to mess with the different sampling parameters (top_p and temp), as well as the length of the generations (gen_len, causes a recompile when changed).
#
# You can also change other things like per_replica_batch in the previous cells to change how many generations are done in parallel. A larger batch has higher latency but higher throughput when measured in tokens generated/s. This is useful for doing things like best-of-n cherry picking.
#
# *Tip for best results: Make sure your prompt does not have any trailing spaces, which tend to confuse the model due to the BPE tokenization used during training.*

# %%
# allow text wrapping in generated output: https://stackoverflow.com/a/61401455
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
def infer(context, top_p=0.9, temp=1.0, gen_len=512):
    tokens = tokenizer.encode(context)

    provided_ctx = len(tokens)
    pad_amount = seq - provided_ctx

    padded_tokens = np.pad(tokens, ((pad_amount, 0),)).astype(np.uint32)
    batched_tokens = np.array([padded_tokens] * total_batch)
    length = np.ones(total_batch, dtype=np.uint32) * len(tokens)

    start = time.time()
    output = network.generate(batched_tokens, length, gen_len, {"top_p": np.ones(total_batch) * top_p, "temp": np.ones(total_batch) * temp})

    samples = []
    decoded_tokens = output[1][0]

    for o in decoded_tokens[:, :, 0]:
      samples.append(f"\033[1m{context}\033[0m{tokenizer.decode(o)}")

    print(f"completion done in {time.time() - start:06}s")
    return samples

print(infer("EleutherAI is")[0])
# Out:
# completion done in 59.615925312042236s
#  a team of senior and junior developers that are working together to push back the frontiers of racing videogames. The team is involved in developing a racing videogame from the ground up. It will feature cars and tracks drawn from a creative process.
#
# ELEUTERAI TEAM
#
# HISTORY
#
# Founded by Gianfrancesco Cengia, EleuterAI is an independent videogame development team that started making videogames in 2004.
#
# A young team formed in collaboration between the principle members Gianfrancesco Cengia and Luigi Zampar (as well as Luca Barbero, Rolando Labernini and Simone Trovato). Over a period of five years, the members learned how to write code, how to build efficient software processes and how to design a fun racing game. All the while, they shared an enthusiasm for racing games and the ever-evolving technology that became a shared passion.
#
# After five years of collaboration, the team reached the starting point of its car games. Due to the great success of Formula One 2017, the videogame race team found the confidence to start a new phase of their adventure.
#
# The innovative approach of the team also brought results to the printed world. Indeed, the videogames that the EleuterAI team published in 2014, 2015 and 2016 are among the highest-selling videogames on the French market.
#
# Among the videogame developments produced by the team, Trovato mentions Firepower, Vinicius and Stop and Stares.
#
# The EleuterAI experience also showed the team the opportunity to expand its horizons outside of car racing. Indeed, as of today, the group is involved in developing a videogame based on the legendary Italian car brand Alfa Romeo. The development phase is already underway and will be a challenge and new experience for the team. The project is planned to be released in late 2019.
#
# CHALLENGE
#
# This project will be for the EleuterAI team an extraordinary opportunity to show their capabilities and the expertise acquired in the car race gaming experience. As a result, we could have a videogame of the highest quality.
#
# Team-work and collaboration will be key elements to develop a fun racing experience and will be at the center of the game.
#
# Vision & Values
#
# We are close to our mission, which is to make the best racing videogames. We don’t have any brand vision or values, but we do have a very clear idea of

# %%
#@title  { form-width: "300px" }
top_p = 0.9 #@param {type:"slider", min:0, max:1, step:0.1}
temp = 1 #@param {type:"slider", min:0, max:1, step:0.1}

context = """In a shocking finding, scientist discovered a herd of unicorns living in a remote, previously unexplored valley, in the Andes Mountains. Even more surprising to the researchers was the fact that the unicorns spoke perfect English."""

print(infer(top_p=top_p, temp=temp, gen_len=512, context=context)[0])
# Out:
# completion done in 13.510299682617188s
#  The scientists decided to ask one of the creatures to show them what English sounds like.
#
# The creature was then transported in a private jet to a real-life, windy city, where it was finally placed on the roof of a building, wearing a set of headphones. The scientist proceeded to ask the creature to demonstrate the letter “R”, which turned out to be an “R”-shaped unicorn.
#
# At this point, the scientists expected the creature to start singing, or making a horselike sound. Instead, the unicorn imitated a car horn, roaring “Raaaaaarrrr!”. The scientist chuckled at the unplanned execution. The unicorn finished the demonstration by shouting “Ahhhhhhhhhhhhhhhhh!”, sounding like an escaped convict having an orgasm.
#
# Then the creature, after spending about an hour on the rooftop, as it was exhausted, went to sleep. By chance, the creature’s body was mown down by a steamroller a few hours later, and its body was sent to the scientists.
#
# The scientists analysed the DNA and created a synthetic version of the creature’s horn, and inserted it into a New Zealand sheep. The sheep were taught to use a computer program for spelling, but after the sheep had been taught to pronounce the letter “R”, it would never stop saying it.
#
# Dr. Graeme Lloyd, of the University of Canterbury, New Zealand, said “We created this synthetic horn by the end of the project, and inserted it into the New Zealand sheep. We told the sheep that they had to use the synthetic horn to say “R”, and that they must never say anything else. For a month, the sheep would wake up at dawn, go on to the roof of our office building, and then try to say “R”. In a few weeks, the sheep’s heads would fall off.”
#
# Related
#
# Comments
#
# Before going off to sally forth about the wonders and dangers of the internet, did you perhaps check on BING to see if your best friend had posted up something about you?
# Or, perhaps it’s more likely that you’re living in a fantasy land, which, when looking at that headline, is probably the case.
#
# Actually, that article about unicorns is so unbelievably stupid and self-satifyingly absurd, even I had to
